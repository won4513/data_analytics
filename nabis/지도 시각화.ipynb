# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
boundary = gpd.read_file("C:/Users/guswn/OneDrive/바탕 화면/생활인구/sig.shp",encoding='cp949')

# %%
fig, ax = plt.subplots(figsize=(10, 6))
boundary.plot(ax=ax)
plt.show()

# %%
boundary.loc[boundary['SIG_KOR_NM'] == '고성군', 'SIG_KOR_NM'] = ['고성군(경남)', '고성군(강원)']

# %%
trip=boundary[boundary["SIG_KOR_NM"].isin(["양양군","홍천군","고성군(강원)","태안군","평창군"])]

# %%
trip
# Out:
#     SIG_CD       SIG_ENG_NM SIG_KOR_NM  \
# 147  44825        Taean-gun        태안군
# 239  51720    Hongcheon-gun        홍천군
# 242  51760  Pyeongchang-gun        평창군
# 248  51820      Goseong-gun    고성군(강원)
# 249  51830     Yangyang-gun        양양군
#
#                                               geometry
# 147  MULTIPOLYGON (((895273.913 1877004.910, 895260...
# 239  POLYGON ((1046324.015 1994003.079, 1046427.876...
# 242  POLYGON ((1108660.341 1961857.507, 1108708.907...
# 248  MULTIPOLYGON (((1091705.056 2034023.203, 10917...
# 249  MULTIPOLYGON (((1102146.292 2010704.587, 11021...

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# 첫 번째 데이터를 그립니다.
dark_color=(0.75,0.75,0.75)
boundary.plot(ax=ax, color=dark_color, label='First Shapefile')

# 두 번째 데이터를 그립니다.
trip.plot(ax=ax,edgecolor='black', linewidth=1, label='Second Shapefile')

# 'aspect' 매개변수를 수정합니다.
ax.set_aspect('equal')

# 범례를 추가합니다.
plt.legend()

# plot을 보여줍니다.
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
trip=boundary[boundary["SIG_KOR_NM"].isin(["부여군","홍천군","화순군","계룡시","문경시"])]

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# 첫 번째 데이터를 그립니다.
dark_color=(0.75,0.75,0.75)
boundary.plot(ax=ax, color=dark_color, label='First Shapefile')

# 두 번째 데이터를 그립니다.
trip.plot(ax=ax,edgecolor='black', linewidth=1, label='Second Shapefile')

# 'aspect' 매개변수를 수정합니다.
ax.set_aspect('equal')

# 범례를 추가합니다.
plt.legend()

# plot을 보여줍니다.
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
mm_new_df=pd.read_csv("C:/Users/guswn/OneDrive/바탕 화면/생활인구/new_df.csv",encoding="utf-8")

# %%
mm_new_df
# Out:
#    행정구역  2023년06월_거주자 인구수     22생활인구평균    거주환경지수  관광 활성화 지수
# 0   태백시             38802  2555405.325  0.339127       16.6
# 1   삼척시             63115  3565265.747  0.530092       42.2
# 2   홍천군             67448  4075700.482  0.565565       62.3
# 3   횡성군             46439  2649233.625  0.320384       32.9
# 4   영월군             37425  1861082.523  0.514852       29.3
# ..  ...               ...          ...       ...        ...
# 66  하동군             41959  1787245.254  0.285601       21.2
# 67  산청군             34025  1685688.525  0.295084       29.4
# 68  함양군             37172  2047514.484  0.237480       18.3
# 69  거창군             60198  2706173.278  0.460788       20.0
# 70  합천군             41455  2091035.929  0.262615       18.2
#
# [71 rows x 5 columns]

# %%
mm_new_df
# Out:
#    행정구역  2023년06월_거주자 인구수     22생활인구평균    거주환경지수  관광 활성화 지수
# 0   태백시             38802  2555405.325  0.339127       16.6
# 1   삼척시             63115  3565265.747  0.530092       42.2
# 2   홍천군             67448  4075700.482  0.565565       62.3
# 3   횡성군             46439  2649233.625  0.320384       32.9
# 4   영월군             37425  1861082.523  0.514852       29.3
# ..  ...               ...          ...       ...        ...
# 66  하동군             41959  1787245.254  0.285601       21.2
# 67  산청군             34025  1685688.525  0.295084       29.4
# 68  함양군             37172  2047514.484  0.237480       18.3
# 69  거창군             60198  2706173.278  0.460788       20.0
# 70  합천군             41455  2091035.929  0.262615       18.2
#
# [71 rows x 5 columns]

# %%
boundary_1=boundary[boundary["SIG_KOR_NM"].isin(df["행정구역"])]

# %%
boundary_1=boundary_1.rename(columns={"SIG_KOR_NM":"행정구역"})

# %%
boundary_1
# Out:
#     SIG_CD       SIG_ENG_NM     행정구역  \
# 49   27720        Gunwi-gun      군위군
# 124  43720        Boeun-gun      보은군
# 125  43730      Okcheon-gun      옥천군
# 126  43740    Yeongdong-gun      영동군
# 127  43745  Jeungpyeong-gun      증평군
# ..     ...              ...      ...
# 245  51790     Hwacheon-gun      화천군
# 246  51800       Yanggu-gun      양구군
# 247  51810         Inje-gun      인제군
# 248  51820      Goseong-gun  고성군(강원)
# 249  51830     Yangyang-gun      양양군
#
#                                               geometry
# 49   POLYGON ((1085756.137 1814814.379, 1085754.990...
# 124  POLYGON ((1026216.235 1845675.010, 1026236.303...
# 125  POLYGON ((1013285.761 1827223.828, 1013302.772...
# 126  POLYGON ((1030921.717 1813295.527, 1030947.554...
# 127  POLYGON ((1003329.529 1867824.774, 1003386.941...
# ..                                                 ...
# 245  POLYGON ((1027779.614 2032000.017, 1027951.841...
# 246  MULTIPOLYGON (((1046391.747 2032451.649, 10463...
# ...

# %%
boundary2=pd.merge(boundary_1,mm_new_df,how="inner",on="행정구역")

# %%
boundary2
# Out:
#    SIG_CD       SIG_ENG_NM     행정구역  \
# 0   27720        Gunwi-gun      군위군
# 1   43720        Boeun-gun      보은군
# 2   43730      Okcheon-gun      옥천군
# 3   43740    Yeongdong-gun      영동군
# 4   43745  Jeungpyeong-gun      증평군
# ..    ...              ...      ...
# 66  51790     Hwacheon-gun      화천군
# 67  51800       Yanggu-gun      양구군
# 68  51810         Inje-gun      인제군
# 69  51820      Goseong-gun  고성군(강원)
# 70  51830     Yangyang-gun      양양군
#
#                                              geometry  2023년06월_거주자 인구수  \
# 0   POLYGON ((1085756.137 1814814.379, 1085754.990...             23139
# 1   POLYGON ((1026216.235 1845675.010, 1026236.303...             31246
# 2   POLYGON ((1013285.761 1827223.828, 1013302.772...             49139
# 3   POLYGON ((1030921.717 1813295.527, 1030947.554...             44520
# 4   POLYGON ((1003329.529 1867824.774, 1003386.941...             37232
# ..                                                ...               ...
# ...

# %%
colors = [(0, 0.3, 0.6), (1, 1, 1), (0.8, 0, 0)]  # 각각의 색상 튜플 (RGB)
cmap_name = 'custom_color_map'
cm = LinearSegmentedColormap.from_list(cmap_name, colors, N=10)


# 플롯 생성
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# 거주자 인구수에 대한 지도 시각화
boundary.plot(ax=axes[0], color="white")
boundary2.plot(column='22생활인구평균', ax=axes[0], legend=True, cmap=cm, legend_kwds={'label': "생활 인구수"})

ax.set_aspect('equal')
axes[0].set_title('생활 인구수')

# 거주환경지수에 대한 지도 시각화
boundary.plot(ax=axes[1], color="white")
boundary2.plot(column='거주환경지수', ax=axes[1], legend=True, cmap=cm, legend_kwds={'label': "거주환경지수"})
ax.set_aspect('equal')
axes[1].set_title('거주환경지수')

# 관광 활성화 지수에 대한 지도 시각화
boundary.plot(ax=axes[2], color="white")
boundary2.plot(column='관광 활성화 지수', ax=axes[2], legend=True, cmap=cm, legend_kwds={'label': "관광 활성화 지수"})
ax.set_aspect('equal')
axes[2].set_title('관광 활성화 지수')

#거주자 인구수
boundary.plot(ax=axes[3], color="white")
boundary2.plot(column='2023년06월_거주자 인구수', ax=axes[3], legend=True, cmap=cm, legend_kwds={'label': "거주자 인구수"})
ax.set_aspect('equal')
axes[3].set_title('거주자 인구수')

# 그래프 출력
plt.show()
